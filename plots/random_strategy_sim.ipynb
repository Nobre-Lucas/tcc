# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leitura dos dados
df = pd.read_csv('../data/simulation/random_strategy_sim.csv')

# %%
# Análise Descritiva
df.describe()
# Out:
#        trees_by_client     round     sim_time         mse1  pearson_corr1  \
# count        80.000000  80.00000    80.000000    80.000000      80.000000
# mean        138.375000   1.98750   230.645266  6438.363363       0.598116
# std          77.483257   0.81898   745.638606   112.947418       0.008747
# min          10.000000   1.00000     0.139605  6386.705599       0.527265
# 25%          70.000000   1.00000     0.526659  6386.705599       0.595892
# 50%         140.000000   2.00000     0.970088  6455.514751       0.596313
# 75%         202.500000   3.00000    28.775360  6460.041957       0.602676
# max         270.000000   3.00000  4884.856431  7378.053205       0.602676
#
#               mse2  pearson_corr2         mse3  pearson_corr3         mse4  \
# count    80.000000      80.000000    80.000000      80.000000    80.000000
# mean   6442.176050       0.598090  6437.838205       0.598126  6437.743994
# std     145.520563       0.008962   108.534406       0.008665   107.745276
# min    6386.705599       0.525174  6386.705599       0.528070  6386.705599
# 25%    6386.705599       0.595892  6386.705599       0.595892  6386.705599
# 50%    6455.514751       0.596313  6455.514751       0.596313  6455.514751
# 75%    6460.041957       0.602676  6460.041957       0.602676  6460.041957
# max    7683.068153       0.602676  7336.040537       0.602676  7328.503674
#
#        pearson_corr4
# count      80.000000
# mean        0.598182
# std         0.008209
# min         0.532545
# 25%         0.595892
# 50%         0.596313
# 75%         0.602676
# max         0.602676

# %%
# Relacionamento entre Variáveis
df.corr()
# Out:
#                  trees_by_client     round  sim_time      mse1  pearson_corr1  \
# trees_by_client         1.000000 -0.026256  0.488371  0.094917      -0.151708
# round                  -0.026256  1.000000 -0.002742 -0.127819       0.124371
# sim_time                0.488371 -0.002742  1.000000  0.048835      -0.066358
# mse1                    0.094917 -0.127819  0.048835  1.000000      -0.997697
# pearson_corr1          -0.151708  0.124371 -0.066358 -0.997697       1.000000
# mse2                    0.029713 -0.131200  0.029702  0.996900      -0.989274
# pearson_corr2          -0.143177  0.124951 -0.063854 -0.998348       0.999946
# mse3                    0.106895 -0.127108  0.052336  0.999894      -0.998576
# pearson_corr3          -0.155100  0.124137 -0.067354 -0.997407       0.999991
# mse4                    0.109145 -0.126971  0.052993  0.999851      -0.998717
# pearson_corr4          -0.175138  0.122705 -0.073224 -0.995343       0.999589
#
#                      mse2  pearson_corr2      mse3  pearson_corr3      mse4  \
# trees_by_client  0.029713      -0.143177  0.106895      -0.155100  0.109145
# round           -0.131200       0.124951 -0.127108       0.124137 -0.126971
# sim_time         0.029702      -0.063854  0.052336      -0.067354  0.052993
# mse1             0.996900      -0.998348  0.999894      -0.997407  0.999851
# pearson_corr1   -0.989274       0.999946 -0.998576       0.999991 -0.998717
# mse2             1.000000      -0.990739  0.995651      -0.988660  0.995393
# pearson_corr2   -0.990739       1.000000 -0.999076       0.999894 -0.999189
# mse3             0.995651      -0.999076  1.000000      -0.998346  0.999996
# pearson_corr3   -0.988660       0.999894 -0.998346       1.000000 -0.998499
# mse4             0.995393      -0.999189  0.999996      -0.998499  1.000000
# pearson_corr4   -0.984678       0.999236 -0.996637       0.999699 -0.996857
#
#                  pearson_corr4
# trees_by_client      -0.175138
# round                 0.122705
# sim_time             -0.073224
# mse1                 -0.995343
# pearson_corr1         0.999589
# mse2                 -0.984678
# pearson_corr2         0.999236
# mse3                 -0.996637
# pearson_corr3         0.999699
# mse4                 -0.996857
# pearson_corr4         1.000000

# %%
# Relacionamento entre Variáveis - Heatmap
corr_matrix = df.corr()

# Configuração do heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %%
# Comparação de Rounds
df.groupby('round').mean()
# Out:
#        trees_by_client    sim_time         mse1  pearson_corr1         mse2  \
# round
# 1                140.0  189.749912  6462.234568       0.596307  6473.531418
# 2                140.0  317.336144  6425.215572       0.599128  6425.215572
# 3                135.0  183.088375  6427.227511       0.598945  6427.227511
#
#        pearson_corr2         mse3  pearson_corr3         mse4  pearson_corr4
# round
# 1           0.596229  6460.678543       0.596337  6460.399400       0.596502
# 2           0.599128  6425.215572       0.599128  6425.215572       0.599128
# 3           0.598945  6427.227511       0.598945  6427.227511       0.598945

# %%
# Comparação de Rounds
round_comparison = df.groupby('round').mean().round(2)  # Arredondar para 2 casas decimais

# Renomear as colunas
round_comparison.columns = ['trees', 'sim_time', 'mse1', 'pearson1', 'mse2', 'pearson2', 'mse3', 'pearson3', 'mse4', 'pearson4']

# Criar uma tabela para visualização com ajustes de fonte e tamanho
fig, ax = plt.subplots(figsize=(10, 4))
ax.axis('off')  # Desativa os eixos para uma aparência mais limpa

# Ajustes de fonte e tamanho
font_size = 10
table = ax.table(cellText=round_comparison.values, colLabels=round_comparison.columns, loc='center', cellLoc='center', fontsize=font_size)
table.auto_set_font_size(False)
table.set_fontsize(font_size)

# Salvar a tabela como uma imagem
plt.savefig('random_strategy_group_by_round.png', bbox_inches='tight')
plt.show()

# %%
# Análise de Tendências Temporais com uma métrica específica (por exemplo, mse1)
df.plot(x='sim_time', y='mse1', kind='scatter')
plt.title('MSE1 em função do tempo de simulação')
plt.xlabel('Tempo de Simulação')
plt.ylabel('MSE1')
plt.show()

# %%
# Comparação entre Pearson_corr e número de árvores
df.plot(x='trees_by_client', y='pearson_corr1', kind='scatter')
plt.title('Pearson Corr1 em relação ao número de árvores por cliente')
plt.xlabel('Número de Árvores por Cliente')
plt.ylabel('Pearson Corr1')
plt.show()

# %%
# Plotar gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['sim_time'], alpha=0.5)
plt.title('Relação entre sim_time e simulação')
plt.xlabel('iteration')
plt.ylabel('sim_time')
plt.grid(True)
plt.show()

# %%
# Plotar gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(df['trees_by_client'], df['sim_time'], alpha=0.5)
plt.title('Relação entre sim_time e trees_by_client')
plt.xlabel('trees_by_client')
plt.ylabel('sim_time')
plt.grid(True)
plt.show()
