# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leitura dos dados
df = pd.read_csv('../data/simulation/best_forests_strategy_sim.csv', nrows=76)

# %%
# Análise Descritiva
df.describe()
# Out:
#        trees_by_client      round   sim_time         mse1  pearson_corr1  \
# count        76.000000  76.000000  76.000000    76.000000      76.000000
# mean        131.710526   1.986842   2.316627  6708.948663       0.575556
# std          73.636733   0.824515   1.311180   262.511528       0.020158
# min          10.000000   1.000000   0.330005  6368.349417       0.527265
# 25%          70.000000   1.000000   1.144720  6489.262917       0.566308
# 50%         130.000000   2.000000   2.139457  6746.270681       0.570927
# 75%         192.500000   3.000000   3.335544  6798.820697       0.593404
# max         260.000000   3.000000   5.005085  7378.053205       0.603127
#
#               mse2  pearson_corr2         mse3  pearson_corr3         mse4  \
# count    76.000000      76.000000    76.000000      76.000000    76.000000
# mean   6699.957026       0.576448  6750.672023       0.572658  6713.317136
# std     246.847600       0.018301   238.368045       0.017809   256.007719
# min    6391.540593       0.525174  6363.783461       0.527265  6404.675580
# 25%    6503.475162       0.566476  6516.573988       0.564361  6456.049172
# 50%    6731.835784       0.572756  6781.866302       0.567930  6752.691869
# 75%    6799.076209       0.592102  6843.728435       0.590911  6822.848726
# max    7683.068153       0.601224  7378.053205       0.603566  7378.053205
#
#        pearson_corr4
# count      76.000000
# mean        0.575071
# std         0.019745
# min         0.527265
# 25%         0.564385
# 50%         0.570384
# 75%         0.596103
# max         0.600204

# %% [markdown]
# ## Gráficos Antigos

# %%
# Relacionamento entre Variáveis
df.corr()
# Out:
#                  trees_by_client     round  sim_time      mse1  pearson_corr1  \
# trees_by_client         1.000000 -0.028173  0.825987 -0.422634       0.378439
# round                  -0.028173  1.000000  0.328468 -0.041657       0.037906
# sim_time                0.825987  0.328468  1.000000 -0.422415       0.384487
# mse1                   -0.422634 -0.041657 -0.422415  1.000000      -0.994918
# pearson_corr1           0.378439  0.037906  0.384487 -0.994918       1.000000
# mse2                   -0.457875 -0.107503 -0.440294  0.599096      -0.593293
# pearson_corr2           0.445794  0.076469  0.418056 -0.571275       0.571254
# mse3                   -0.251314 -0.018931 -0.272615  0.617259      -0.588050
# pearson_corr3           0.189489 -0.001998  0.209465 -0.608081       0.587433
# mse4                   -0.562281 -0.043547 -0.538438  0.685828      -0.662288
# pearson_corr4           0.555277  0.030137  0.523686 -0.658924       0.640385
#
#                      mse2  pearson_corr2      mse3  pearson_corr3      mse4  \
# trees_by_client -0.457875       0.445794 -0.251314       0.189489 -0.562281
# round           -0.107503       0.076469 -0.018931      -0.001998 -0.043547
# sim_time        -0.440294       0.418056 -0.272615       0.209465 -0.538438
# mse1             0.599096      -0.571275  0.617259      -0.608081  0.685828
# pearson_corr1   -0.593293       0.571254 -0.588050       0.587433 -0.662288
# mse2             1.000000      -0.984756  0.497741      -0.500104  0.733860
# pearson_corr2   -0.984756       1.000000 -0.477014       0.483078 -0.718833
# mse3             0.497741      -0.477014  1.000000      -0.990113  0.618957
# pearson_corr3   -0.500104       0.483078 -0.990113       1.000000 -0.596253
# mse4             0.733860      -0.718833  0.618957      -0.596253  1.000000
# pearson_corr4   -0.743313       0.739336 -0.585924       0.569193 -0.993687
#
#                  pearson_corr4
# trees_by_client       0.555277
# round                 0.030137
# sim_time              0.523686
# mse1                 -0.658924
# pearson_corr1         0.640385
# mse2                 -0.743313
# pearson_corr2         0.739336
# mse3                 -0.585924
# pearson_corr3         0.569193
# mse4                 -0.993687
# pearson_corr4         1.000000

# %%
# Relacionamento entre Variáveis - Heatmap
corr_matrix = df.corr()

# Configuração do heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Matriz de Correlação entre Variáveis')
plt.show()

# %%
# Comparação de Rounds
df.groupby('round').mean()
# Out:
#        trees_by_client  sim_time         mse1  pearson_corr1         mse2  \
# round
# 1                135.0  1.610620  6726.287789       0.574345  6742.033853
# 2                130.0  2.719812  6699.932318       0.576186  6678.077076
# 3                130.0  2.647689  6699.932318       0.576186  6678.077076
#
#        pearson_corr2         mse3  pearson_corr3         mse4  pearson_corr4
# round
# 1           0.574229  6757.827011       0.572714  6730.994011       0.574128
# 2           0.577602  6746.951429       0.572629  6704.125161       0.575562
# 3           0.577602  6746.951429       0.572629  6704.125161       0.575562

# %%
# Comparação de Rounds
round_comparison = df.groupby('round').mean().round(2)  # Arredondar para 2 casas decimais

# Renomear as colunas
round_comparison.columns = ['trees', 'sim_time', 'mse1', 'pearson1', 'mse2', 'pearson2', 'mse3', 'pearson3', 'mse4', 'pearson4']

# Criar uma tabela para visualização com ajustes de fonte e tamanho
fig, ax = plt.subplots(figsize=(10, 4))
ax.axis('off')  # Desativa os eixos para uma aparência mais limpa

# Ajustes de fonte e tamanho
font_size = 10
table = ax.table(cellText=round_comparison.values, colLabels=round_comparison.columns, loc='center', cellLoc='center', fontsize=font_size)
table.auto_set_font_size(False)
table.set_fontsize(font_size)

# Salvar a tabela como uma imagem
plt.savefig('best_forests_strategy_group_by_round.png', bbox_inches='tight')
plt.show()

# %%
# Análise de Tendências Temporais com uma métrica específica (por exemplo, mse1)
df.plot(x='sim_time', y='mse1', kind='scatter')
plt.title('MSE1 em função do tempo de simulação')
plt.xlabel('Tempo de Simulação')
plt.ylabel('MSE1')
plt.show()

# %%
len(df[['mse1', 'mse2', 'mse3', 'mse4']])
# Out:
# 76

# %%
# Gráfico de dispersão para sim_time em relação a mse1, mse2, mse3 e mse4
plt.figure(figsize=(10, 6))

# Loop através das colunas mse1, mse2, mse3, mse4
for column in ['mse1', 'mse2', 'mse3', 'mse4']:
    plt.scatter(df['sim_time'], df[column], alpha=0.5)

plt.title('Erro Quadrático Médio em relação ao Tempo')
plt.xlabel('sim_time')
plt.ylabel('mse1, mse2, mse3, mse4')
plt.grid(True)
plt.legend(['mse1', 'mse2', 'mse3', 'mse4'])
plt.show()

# %%
# Comparação entre Pearson_corr e número de árvores
df.plot(x='trees_by_client', y='pearson_corr1', kind='scatter')
plt.title('Pearson Corr1 em relação ao número de árvores por cliente')
plt.xlabel('Número de Árvores por Cliente')
plt.ylabel('Pearson Corr1')
plt.show()

# %%
# Gráfico de dispersão para trees_by_client em relação a pearson_corr1, pearson_corr2, pearson_corr3 e pearson_corr4
plt.figure(figsize=(10, 6))

# Loop através das colunas pearson_corr1, pearson_corr2, pearson_corr3, pearson_corr4
for column in ['pearson_corr1', 'pearson_corr2', 'pearson_corr3', 'pearson_corr4']:
    plt.scatter(df['trees_by_client'], df[column], alpha=0.5)

plt.title('Correlação de Pearson em relação ao Número de Árvores por Cliente')
plt.xlabel('trees_by_client')
plt.ylabel('pearson_corr1, pearson_corr2, pearson_corr3, pearson_corr4')
plt.grid(True)
plt.legend(['pearson_corr1', 'pearson_corr2', 'pearson_corr3', 'pearson_corr4'])
plt.show()

# %%
# Plotar gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['sim_time'], alpha=0.5)
plt.title('Relação entre Tempo de Simulação e Iteração da Simulação')
plt.xlabel('iteration')
plt.ylabel('sim_time')
plt.grid(True)
plt.show()

# %%
# Plotar gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.scatter(df['trees_by_client'], df['sim_time'], alpha=0.5)
plt.title('Relação entre Tempo de Simulação e Número de Árvores por Cliente')
plt.xlabel('trees_by_client')
plt.ylabel('sim_time')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Gráficos Novos

# %%
# Calcular a média das colunas pearson (1 a 4)
df['pearson_mean'] = df[['pearson_corr1', 'pearson_corr2', 'pearson_corr3', 'pearson_corr4']].mean(axis=1)

centralized_trees = pd.read_csv('../data/centralized_data/n_estimators.csv', nrows=28)
centralized_pearson_corr = pd.read_csv('../data/centralized_data/n_estimators_pearson_corr_unchange.csv', nrows=28)

centralized_mean = centralized_pearson_corr['pearson_corr'].mean()

# Gráfico de dispersão
plt.figure(figsize=(10, 6))
plt.plot(df['trees_by_client'], df['pearson_mean'], color='b', label=f'Algoritmo Federado')
plt.axhline(y=centralized_mean, color='r', linestyle='--', label=f'Algoritmo Centralizado')
plt.title('Correlação de Pearson por Quantidade de Árvores por Cliente')
plt.xlabel('Quantidade de Árvores por Cliente')
plt.ylabel('Correlação de Pearson Média')
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.show()
